# %%
import pandas as pd
df = pd.read_csv("data.csv")
df
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2020                     Level 1                99999
# 1      2020                     Level 1                99999
# 2      2020                     Level 1                99999
# 3      2020                     Level 1                99999
# 4      2020                     Level 1                99999
# ...     ...                         ...                  ...
# 37075  2013                     Level 3                 ZZ11
# 37076  2013                     Level 3                 ZZ11
# 37077  2013                     Level 3                 ZZ11
# 37078  2013                     Level 3                 ZZ11
# 37079  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
details = {
    'name': ['ravi','shivam','hardik','aryan','rishi','chinu','shubham'],
    'height' :[6, 6, 6.2, 4, 5.8, 6.8, 5.8]
}
df = pd.DataFrame(details)
df
# Out:
#       name  height
# 0     ravi     6.0
# 1   shivam     6.0
# 2   hardik     6.2
# 3    aryan     4.0
# 4    rishi     5.8
# 5    chinu     6.8
# 6  shubham     5.8

# %%
df.shape
# Out:
# (7, 2)

# %%
row,columns = df.shape
row
# Out:
# 7

# %%
columns
# Out:
# 2

# %%
df[1:6]
# Out:
#      name  height
# 1  shivam     6.0
# 2  hardik     6.2
# 3   aryan     4.0
# 4   rishi     5.8
# 5   chinu     6.8

# %%
df.head()
# Out:
#      name  height
# 0    ravi     6.0
# 1  shivam     6.0
# 2  hardik     6.2
# 3   aryan     4.0
# 4   rishi     5.8

# %%
df.tail()
# Out:
#       name  height
# 2   hardik     6.2
# 3    aryan     4.0
# 4    rishi     5.8
# 5    chinu     6.8
# 6  shubham     5.8

# %%
df.tail(1)
# Out:
#       name  height
# 6  shubham     5.8

# %%
df.head(1)
# Out:
#    name  height
# 0  ravi     6.0

# %%
df.columns
# Out:
# Index(['name', 'height'], dtype='object')

# %%
df['name'] #This can be written as df.name but this way is more comfortable
# Out:
# 0       ravi
# 1     shivam
# 2     hardik
# 3      aryan
# 4      rishi
# 5      chinu
# 6    shubham
# Name: name, dtype: object

# %%
df[['name','height']]
# Out:
#       name  height
# 0     ravi     6.0
# 1   shivam     6.0
# 2   hardik     6.2
# 3    aryan     4.0
# 4    rishi     5.8
# 5    chinu     6.8
# 6  shubham     5.8

# %%
df['height'].max()
# Out:
# 6.8

# %%
df['height'].min()
# Out:
# 4.0

# %%
df['height'].mean()
# Out:
# 5.799999999999999

# %%
df['height'].std()
# Out:
# 0.8640987597877147

# %%
df.describe()
# Out:
#          height
# count  7.000000
# mean   5.800000
# std    0.864099
# min    4.000000
# 25%    5.800000
# 50%    6.000000
# 75%    6.100000
# max    6.800000

# %%
df[['name','height']][df.height==df['height'].max()]
# Out:
#     name  height
# 5  chinu     6.8

# %%
df.index
# Out:
# Float64Index([6.0, 6.0, 6.2, 4.0, 5.8, 6.8, 5.8], dtype='float64', name='height')

# %%
df.set_index('height') #this is true. Just because I have deleted saved file it is showing error
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-61-97188cd226ba> in <module>
# ----> 1 df.set_index('height')
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4725
#    4726         if missing:
# -> 4727             raise KeyError(f"None of {missing} are in the columns")
#    4728
#    4729         if inplace:
#
# KeyError: "None of ['height'] are in the columns"

# %%
df
# Out:
#            name
# height
# 6.0        ravi
# 6.0      shivam
# 6.2      hardik
# 4.0       aryan
# 5.8       rishi
# 6.8       chinu
# 5.8     shubham

# %%
df.index #Checking if my indexes changed or not
# Out:
# Float64Index([6.0, 6.0, 6.2, 4.0, 5.8, 6.8, 5.8], dtype='float64', name='height')

# %%
df.loc[6.0]
# Out:
#           name
# height
# 6.0       ravi
# 6.0     shivam

# %%
df.reset_index(inplace=True)
df
# Out:
#    index  height     name
# 0      0     6.0     ravi
# 1      1     6.0   shivam
# 2      2     6.2   hardik
# 3      3     4.0    aryan
# 4      4     5.8    rishi
# 5      5     6.8    chinu
# 6      6     5.8  shubham

# %%
df.set_index('name',inplace=True)
df
# Out:
#          index  height
# name
# ravi         0     6.0
# shivam       1     6.0
# hardik       2     6.2
# aryan        3     4.0
# rishi        4     5.8
# chinu        5     6.8
# shubham      6     5.8

# %%
df.loc['ravi']
# Out:
# index     0.0
# height    6.0
# Name: ravi, dtype: float64

# %%
import pandas as pd
df = pd.read_csv("data.csv", header =1) #to print data from skipping first line. we ca also use header= none to remove header
df
# Out:
#        2020  Level 1  99999              All industries  Dollars (millions)  \
# 0      2020  Level 1  99999              All industries  Dollars (millions)
# 1      2020  Level 1  99999              All industries  Dollars (millions)
# 2      2020  Level 1  99999              All industries  Dollars (millions)
# 3      2020  Level 1  99999              All industries  Dollars (millions)
# 4      2020  Level 1  99999              All industries  Dollars (millions)
# ...     ...      ...    ...                         ...                 ...
# 37074  2013  Level 3   ZZ11  Food product manufacturing          Percentage
# 37075  2013  Level 3   ZZ11  Food product manufacturing          Percentage
# 37076  2013  Level 3   ZZ11  Food product manufacturing          Percentage
# 37077  2013  Level 3   ZZ11  Food product manufacturing          Percentage
# 37078  2013  Level 3   ZZ11  Food product manufacturing          Percentage
#
# ...

# %%
df.head()
# Out:
#    2020  Level 1  99999  All industries  Dollars (millions)  H01  \
# 0  2020  Level 1  99999  All industries  Dollars (millions)  H04
# 1  2020  Level 1  99999  All industries  Dollars (millions)  H05
# 2  2020  Level 1  99999  All industries  Dollars (millions)  H07
# 3  2020  Level 1  99999  All industries  Dollars (millions)  H08
# 4  2020  Level 1  99999  All industries  Dollars (millions)  H09
#
#                                       Total income  Financial performance  \
# 0  Sales, government funding, grants and subsidies  Financial performance
# 1                Interest, dividends and donations  Financial performance
# 2                             Non-operating income  Financial performance
# 3                                Total expenditure  Financial performance
# 4                           Interest and donations  Financial performance
#
#    733,258  \
# 0  660,630
# 1   54,342
# 2   18,285
# 3  654,872
# 4   32,730
#
# ...

# %%
import pandas as pd
df = pd.read_csv("data.csv", na_values=["2020"])
df
# Out:
#          Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0         NaN                     Level 1                99999
# 1         NaN                     Level 1                99999
# 2         NaN                     Level 1                99999
# 3         NaN                     Level 1                99999
# 4         NaN                     Level 1                99999
# ...       ...                         ...                  ...
# 37075  2013.0                     Level 3                 ZZ11
# 37076  2013.0                     Level 3                 ZZ11
# 37077  2013.0                     Level 3                 ZZ11
# 37078  2013.0                     Level 3                 ZZ11
# 37079  2013.0                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
import pandas as pd
df = pd.read_csv("data.csv")
df
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2020                     Level 1                99999
# 1      2020                     Level 1                99999
# 2      2020                     Level 1                99999
# 3      2020                     Level 1                99999
# 4      2020                     Level 1                99999
# ...     ...                         ...                  ...
# 37075  2013                     Level 3                 ZZ11
# 37076  2013                     Level 3                 ZZ11
# 37077  2013                     Level 3                 ZZ11
# 37078  2013                     Level 3                 ZZ11
# 37079  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
df.columns
# Out:
# Index(['Year', 'Industry_aggregation_NZSIOC', 'Industry_code_NZSIOC',
#        'Industry_name_NZSIOC', 'Units', 'Variable_code', 'Variable_name',
#        'Variable_category', 'Value', 'Industry_code_ANZSIC06'],
#       dtype='object')

# %%
df.to_csv('data.csv', columns= ['Year',"Value"])
df
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2020                     Level 1                99999
# 1      2020                     Level 1                99999
# 2      2020                     Level 1                99999
# 3      2020                     Level 1                99999
# 4      2020                     Level 1                99999
# ...     ...                         ...                  ...
# 37075  2013                     Level 3                 ZZ11
# 37076  2013                     Level 3                 ZZ11
# 37077  2013                     Level 3                 ZZ11
# 37078  2013                     Level 3                 ZZ11
# 37079  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
import pandas as pd               #to convert any cell
def convert_year_cell(cell):
    if cell == 2020:
        return 2021
    return cell
df = pd.read_csv("data.csv", converters= {
    'year': convert_year_cell,
    'values': convert_year_cell
})

df
# Out:
#        Unnamed: 0  Year    Value
# 0               0  2020  733,258
# 1               1  2020  660,630
# 2               2  2020   54,342
# 3               3  2020   18,285
# 4               4  2020  654,872
# ...           ...   ...      ...
# 37075       37075  2013       52
# 37076       37076  2013       40
# 37077       37077  2013       12
# 37078       37078  2013        5
# 37079       37079  2013       46
#
# [37080 rows x 3 columns]

# %%
df.reset_index()
# Out:
#        index  Unnamed: 0  Year    Value
# 0          0           0  2020  733,258
# 1          1           1  2020  660,630
# 2          2           2  2020   54,342
# 3          3           3  2020   18,285
# 4          4           4  2020  654,872
# ...      ...         ...   ...      ...
# 37075  37075       37075  2013       52
# 37076  37076       37076  2013       40
# 37077  37077       37077  2013       12
# 37078  37078       37078  2013        5
# 37079  37079       37079  2013       46
#
# [37080 rows x 4 columns]

# %%
df.set_index('Year', inplace= True)
df
# Out:
#       Unnamed: 0    Value
# Year
# 2020           0  733,258
# 2020           1  660,630
# 2020           2   54,342
# 2020           3   18,285
# 2020           4  654,872
# ...          ...      ...
# 2013       37075       52
# 2013       37076       40
# 2013       37077       12
# 2013       37078        5
# 2013       37079       46
#
# [37080 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Value'], dtype='object')

# %%
import pandas as pd
df  = pd.read_csv("data.csv")
df
# Out:
#        Unnamed: 0  Year    Value
# 0               0  2020  733,258
# 1               1  2020  660,630
# 2               2  2020   54,342
# 3               3  2020   18,285
# 4               4  2020  654,872
# ...           ...   ...      ...
# 37075       37075  2013       52
# 37076       37076  2013       40
# 37077       37077  2013       12
# 37078       37078  2013        5
# 37079       37079  2013       46
#
# [37080 rows x 3 columns]

# %%
df.set_index('Year', inplace= True)
df
# Out:
#       Unnamed: 0    Value
# Year
# 2020           0  733,258
# 2020           1  660,630
# 2020           2   54,342
# 2020           3   18,285
# 2020           4  654,872
# ...          ...      ...
# 2013       37075       52
# 2013       37076       40
# 2013       37077       12
# 2013       37078        5
# 2013       37079       46
#
# [37080 rows x 2 columns]

# %%
df.loc[2020]
# Out:
#       Unnamed: 0    Value
# Year
# 2020           0  733,258
# 2020           1  660,630
# 2020           2   54,342
# 2020           3   18,285
# 2020           4  654,872
# ...          ...      ...
# 2020        4630       77
# 2020        4631       27
# 2020        4632       17
# 2020        4633        8
# 2020        4634       45
#
# [4635 rows x 2 columns]

# %%
df.to_csv(index= False)
df
# Out:
#       Unnamed: 0    Value
# Year
# 2020           0  733,258
# 2020           1  660,630
# 2020           2   54,342
# 2020           3   18,285
# 2020           4  654,872
# ...          ...      ...
# 2013       37075       52
# 2013       37076       40
# 2013       37077       12
# 2013       37078        5
# 2013       37079       46
#
# [37080 rows x 2 columns]

# %%
df_stocks = pd.DataFrame({
    'day1': [99,33,44,22,44,55],
    'day2' : [66,22,33,411,44,22]
})

df_weather = pd.DataFrame({
    'day' : ['1/1/1','2,2,2','3/3/3'],
    'temperature': [20,30,40]
})
with pd.ExcelWriter('data.xlsx') as writer: #Here I didnt have excel file I have csv file thats why it shows error otherwise this is the correct formualae to add another columns in different sheets in excel.
    df_stocks.to_excel(writer, sheet_name = 'stocks')
    df_weather.to_excel9writer,sheet_name = 'weather)'
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-a0a16e9b13b1> in <module>
#      10 with pd.ExcelWriter('data.xlsx') as writer:
#      11     df_stocks.to_excel(writer, sheet_name = 'stocks')
# ---> 12     df_weather.to_excel9writer,sheet_name = 'weather)'
#
# ValueError: too many values to unpack (expected 2)

# %%
import pandas as pd
df = pd.read_excel("weather.xlsx")
df
# Out:
#      Outlook  Temp  Humidity Windy     Class
# 0      sunny    75        70   yes      Play
# 1      sunny    80        90   yes  DontPlay
# 2      sunny    85        85    no  DontPlay
# 3      sunny    72        95    no  DontPlay
# 4      sunny    69        70    no      Play
# 5   overcast    72        90   yes      Play
# 6   overcast    83        78    no      Play
# 7   overcast    64        65   yes      Play
# 8   overcast    81        75    no      Play
# 9       rain    71        80   yes  DontPlay
# 10      rain    65        70   yes  DontPlay
# 11      rain    75        80    no      Play
# 12      rain    68        80    no      Play
# 13      rain    70        96    no      Play

# %%
import pandas as pd
def convert_Outlook_cell(cell):
    if cell == "sunny":
            return "Hot"
    return "sunny"
df = pd.read_excel("weather.xlsx", "Sheet1", converters = {
    "sunny": convert_Outlook_cell,
})
df
#because I dont have excel so there is no sheet in spreadsheet otherwise in this way we can create a new sheet with different input cells
